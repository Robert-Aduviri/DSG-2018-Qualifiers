# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os, math
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from pandas_summary import DataFrameSummary
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 400)
sns.set()

os.chdir('../..')
from src import utils

# %%
DATA        = Path('data')
RAW         = DATA/'raw'
INTERIM     = DATA/'interim'
PROCESSED   = DATA/'processed'
SUBMISSIONS = DATA/'submissions'

# %% [markdown]
# # Data

# %%
challenge  = pd.read_csv(RAW/'Challenge_20180423.csv', low_memory=False)
customer   = pd.read_csv(RAW/'Customer.csv', low_memory=False)
isin       = pd.read_csv(RAW/'Isin.csv', low_memory=False)
market     = pd.read_csv(RAW/'Market.csv', low_memory=False)
macro      = pd.read_csv(RAW/'MarketData_Macro.csv', low_memory=False)
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
trade      = pd.read_csv(RAW/'Trade.csv', low_memory=False)

# %%
train = pd.merge(trade, customer, how='left', on='CustomerIdx')
train = pd.merge(train, isin, how='left', on='IsinIdx')

# %%
test = pd.merge(challenge, customer, how='left', on='CustomerIdx')
test = pd.merge(test, isin, how='left', on='IsinIdx')

# %%
# same date column name
train['DateKey'] = train['TradeDateKey']
train.drop('TradeDateKey', axis=1, inplace=True)

# %%
# drop extra columns 
extra_cols = ['Price', 'TradeStatus', 'NotionalEUR']
train.drop(extra_cols, axis=1, inplace=True)

# %%
# keep same column order
cols = list(train.columns)
test = test[cols + ['PredictionIdx']].copy()

# %%
# keep same column order
cols = list(train.columns)
test = test[cols + ['PredictionIdx']].copy()

# %%
# Heuristic for num columns
id_cols = ['CustomerIdx', 'IsinIdx']
target_col = 'CustomerInterest'
num_cols = [c for c in train._get_numeric_data().columns if c not in id_cols + [target_col, 'TickerIdx']]
cat_cols = [c for c in train.columns if c not in id_cols + num_cols + [target_col]]

# %%
train.drop(id_cols + [target_col], axis=1).columns
# Out:
# Index(['BuySell', 'Sector', 'Subsector', 'Region_x', 'Country', 'TickerIdx',
#        'ActualMaturityDateKey', 'IssueDateKey', 'Seniority', 'Currency',
#        'ActivityGroup', 'Region_y', 'Activity', 'RiskCaptain', 'Owner',
#        'CompositeRating', 'IndustrySector', 'IndustrySubgroup', 'MarketIssue',
#        'IssuedAmount', 'CouponType', 'DateKey'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['CustomerIdx', 'IsinIdx', 'BuySell', 'CustomerInterest', 'Sector',
#        'Subsector', 'Region_x', 'Country', 'TickerIdx',
#        'ActualMaturityDateKey', 'IssueDateKey', 'Seniority', 'Currency',
#        'ActivityGroup', 'Region_y', 'Activity', 'RiskCaptain', 'Owner',
#        'CompositeRating', 'IndustrySector', 'IndustrySubgroup', 'MarketIssue',
#        'IssuedAmount', 'CouponType', 'DateKey'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %%
from src.utils import apply_cats
for col in cat_cols:
    train[col] = train[col].astype('category').cat.as_ordered()
apply_cats(test, train)

# %%
for col in cat_cols:
    train[col] = train[col].cat.codes
    test[col] = test[col].cat.codes

# %%
id_cols = ['Country', 'Subsector']

# %%
train.drop(id_cols, axis=1)
test.drop(id_cols, axis=1).columns
# Out:
# Index(['CustomerIdx', 'IsinIdx', 'BuySell', 'CustomerInterest', 'Sector',
#        'Region_x', 'TickerIdx', 'ActualMaturityDateKey', 'IssueDateKey',
#        'Seniority', 'Currency', 'ActivityGroup', 'Region_y', 'Activity',
#        'RiskCaptain', 'Owner', 'CompositeRating', 'IndustrySector',
#        'IndustrySubgroup', 'MarketIssue', 'IssuedAmount', 'CouponType',
#        'DateKey', 'PredictionIdx'],
#       dtype='object')

# %% [markdown]
# # Cross validation

# %%
import time, pprint
from sklearn.model_selection import KFold

kfolds = KFold(n_splits=5, shuffle=True, random_state=42)
pp = pprint.PrettyPrinter(indent=3)

# %%
from sklearn.metrics import roc_auc_score

# globals: [cat_indices]
def fit_model(model, model_name, X_trn, y_trn, X_val, y_val):
    if model_name in ['XGBClassifier', 'LGBMClassifier']:
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  early_stopping_rounds=30,
                  eval_metric='auc')
    elif model_name == 'CatBoostClassifier':
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  use_best_model=True,
                  cat_features=cat_indices)
    else:
        model.fit(X_trn, y_trn)
        
def calculate_metrics(model, metrics, X_trn, y_trn, X_val, y_val):
    metric_function = {'auc': roc_auc_score}
    dset = {'trn': {'X': X_trn, 'y': y_trn},
            'val': {'X': X_val, 'y': y_val}}
    
    for d in dset:
        y_pred = model.predict(dset[d]['X'])
        for m in metrics:
            metrics[m][d] += [metric_function[m](dset[d]['y'], y_pred)]
                
    pp.pprint(metrics)
    print()

# %%
# globals: [kfolds]
def run_model(model, X, y, X_test, metric_names, results=None, dataset_desc='', params_desc=''):
    model_name = str(model.__class__).split('.')[-1].replace('>','').replace("'",'')
    print(model_name, '\n')
    if results is None: results = pd.DataFrame()
    metrics = {metric: {'trn': [], 'val': []} for metric in metric_names}
    y_test = np.zeros((len(X_test)))
    start = time.time()
    for trn_idx, val_idx in kfolds.split(X, y):
        print('Training fold')
        fit_model(model, model_name, 
                          X.iloc[trn_idx], y.iloc[trn_idx],
                          X.iloc[val_idx], y.iloc[val_idx])
        calculate_metrics(model, metrics, 
                          X.iloc[trn_idx], y.iloc[trn_idx],
                          X.iloc[val_idx], y.iloc[val_idx])
        y_test += model.predict(X_test)
    y_test /= kfolds.n_splits
    end = time.time()
    means = {f'{d}_{m}_mean': np.mean(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    stds  = {f'{d}_{m}_std': np.std(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    metadata = {'model': model_name, 'dataset': dataset_desc,
                'params': params_desc, 'time': round(end - start, 2)}
    pp.pprint(means)
    results = results.append(pd.Series({**metadata, **means, **stds}), ignore_index=True)
    return y_test, metrics, results

# %%
train.columns
# Out:
# Index(['CustomerIdx', 'IsinIdx', 'BuySell', 'CustomerInterest', 'Sector',
#        'Subsector', 'Region_x', 'Country', 'TickerIdx',
#        'ActualMaturityDateKey', 'IssueDateKey', 'Seniority', 'Currency',
#        'ActivityGroup', 'Region_y', 'Activity', 'RiskCaptain', 'Owner',
#        'CompositeRating', 'IndustrySector', 'IndustrySubgroup', 'MarketIssue',
#        'IssuedAmount', 'CouponType', 'DateKey'],
#       dtype='object')

# %%
from lightgbm import LGBMClassifier

# %%
metric_names = ['auc']

# %%
# %%time
y_test, metrics, results = run_model(
                            LGBMClassifier(),
                            train.drop(id_cols + [target_col], axis=1),
                            train[target_col],
                            test.drop(id_cols + [target_col, 'PredictionIdx'], axis=1),
                            metric_names, None, 
                            params_desc='default',
                            dataset_desc='metadata-only')
# Out:
# LGBMClassifier
#
# Training fold
# [1]	valid_0's auc: 0.842871
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.870019
# [3]	valid_0's auc: 0.877994
# [4]	valid_0's auc: 0.885615
# [5]	valid_0's auc: 0.886209
# [6]	valid_0's auc: 0.894305
# [7]	valid_0's auc: 0.906362
# [8]	valid_0's auc: 0.916003
# [9]	valid_0's auc: 0.917865
# [10]	valid_0's auc: 0.927489
# [11]	valid_0's auc: 0.933568
# [12]	valid_0's auc: 0.934782
# [13]	valid_0's auc: 0.94946
# [14]	valid_0's auc: 0.950466
# [15]	valid_0's auc: 0.958871
# [16]	valid_0's auc: 0.962884
# [17]	valid_0's auc: 0.966402
# [18]	valid_0's auc: 0.968304
# [19]	valid_0's auc: 0.969127
# [20]	valid_0's auc: 0.970282
# [21]	valid_0's auc: 0.970643
# [22]	valid_0's auc: 0.971466
# [23]	valid_0's auc: 0.973282
# [24]	valid_0's auc: 0.973782
# [25]	valid_0's auc: 0.974765
# [26]	valid_0's auc: 0.975588
# [27]	valid_0's auc: 0.976117
# [28]	valid_0's auc: 0.977239
# [29]	valid_0's auc: 0.978055
# [30]	valid_0's auc: 0.979088
# [31]	valid_0's auc: 0.97969
# [32]	valid_0's auc: 0.980145
# [33]	valid_0's auc: 0.980615
# [34]	valid_0's auc: 0.981383
# [35]	valid_0's auc: 0.981731
# [36]	valid_0's auc: 0.982347
# [37]	valid_0's auc: 0.982604
# [38]	valid_0's auc: 0.983175
# [39]	valid_0's auc: 0.983451
# [40]	valid_0's auc: 0.983681
# [41]	valid_0's auc: 0.983999
# [42]	valid_0's auc: 0.984466
# [43]	valid_0's auc: 0.98472
# [44]	valid_0's auc: 0.984895
# [45]	valid_0's auc: 0.985214
# [46]	valid_0's auc: 0.985478
# [47]	valid_0's auc: 0.985907
# [48]	valid_0's auc: 0.986113
# [49]	valid_0's auc: 0.986341
# [50]	valid_0's auc: 0.986498
# [51]	valid_0's auc: 0.986605
# [52]	valid_0's auc: 0.986827
# [53]	valid_0's auc: 0.986958
# [54]	valid_0's auc: 0.987038
# [55]	valid_0's auc: 0.987195
# [56]	valid_0's auc: 0.987447
# [57]	valid_0's auc: 0.987587
# [58]	valid_0's auc: 0.987612
# [59]	valid_0's auc: 0.987725
# [60]	valid_0's auc: 0.987704
# [61]	valid_0's auc: 0.987826
# [62]	valid_0's auc: 0.987955
# [63]	valid_0's auc: 0.988116
# [64]	valid_0's auc: 0.988214
# [65]	valid_0's auc: 0.988325
# [66]	valid_0's auc: 0.988495
# [67]	valid_0's auc: 0.988661
# [68]	valid_0's auc: 0.988661
# [69]	valid_0's auc: 0.988766
# [70]	valid_0's auc: 0.988896
# [71]	valid_0's auc: 0.98896
# [72]	valid_0's auc: 0.988989
# [73]	valid_0's auc: 0.989072
# [74]	valid_0's auc: 0.989181
# [75]	valid_0's auc: 0.989185
# [76]	valid_0's auc: 0.989326
# [77]	valid_0's auc: 0.989381
# [78]	valid_0's auc: 0.989452
# [79]	valid_0's auc: 0.989482
# [80]	valid_0's auc: 0.989632
# [81]	valid_0's auc: 0.989708
# [82]	valid_0's auc: 0.989746
# [83]	valid_0's auc: 0.989827
# [84]	valid_0's auc: 0.989872
# [85]	valid_0's auc: 0.989935
# [86]	valid_0's auc: 0.989984
# [87]	valid_0's auc: 0.99004
# [88]	valid_0's auc: 0.990077
# [89]	valid_0's auc: 0.990146
# [90]	valid_0's auc: 0.99019
# [91]	valid_0's auc: 0.990228
# [92]	valid_0's auc: 0.990295
# [93]	valid_0's auc: 0.990311
# [94]	valid_0's auc: 0.990383
# [95]	valid_0's auc: 0.990423
# [96]	valid_0's auc: 0.990424
# [97]	valid_0's auc: 0.990474
# [98]	valid_0's auc: 0.990537
# [99]	valid_0's auc: 0.99056
# [100]	valid_0's auc: 0.990652
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990652
# {'auc': {'trn': [0.96313977015192065], 'val': [0.96295505842297879]}}
#
# Training fold
# [1]	valid_0's auc: 0.844961
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.870385
# [3]	valid_0's auc: 0.878448
# [4]	valid_0's auc: 0.886187
# [5]	valid_0's auc: 0.887713
# [6]	valid_0's auc: 0.897462
# [7]	valid_0's auc: 0.908181
# [8]	valid_0's auc: 0.912505
# [9]	valid_0's auc: 0.914369
# [10]	valid_0's auc: 0.925427
# [11]	valid_0's auc: 0.928272
# [12]	valid_0's auc: 0.931219
# [13]	valid_0's auc: 0.941479
# [14]	valid_0's auc: 0.954582
# [15]	valid_0's auc: 0.956385
# [16]	valid_0's auc: 0.964077
# [17]	valid_0's auc: 0.966454
# [18]	valid_0's auc: 0.967551
# [19]	valid_0's auc: 0.969015
# [20]	valid_0's auc: 0.970006
# [21]	valid_0's auc: 0.97098
# [22]	valid_0's auc: 0.97293
# [23]	valid_0's auc: 0.974367
# [24]	valid_0's auc: 0.975216
# [25]	valid_0's auc: 0.97589
# [26]	valid_0's auc: 0.976353
# [27]	valid_0's auc: 0.976648
# [28]	valid_0's auc: 0.978056
# [29]	valid_0's auc: 0.978547
# [30]	valid_0's auc: 0.978957
# [31]	valid_0's auc: 0.980036
# [32]	valid_0's auc: 0.98111
# [33]	valid_0's auc: 0.981506
# [34]	valid_0's auc: 0.982076
# [35]	valid_0's auc: 0.98246
# [36]	valid_0's auc: 0.983002
# [37]	valid_0's auc: 0.983485
# [38]	valid_0's auc: 0.983824
# [39]	valid_0's auc: 0.984223
# [40]	valid_0's auc: 0.984518
# [41]	valid_0's auc: 0.98493
# [42]	valid_0's auc: 0.985157
# [43]	valid_0's auc: 0.985218
# [44]	valid_0's auc: 0.985676
# [45]	valid_0's auc: 0.985804
# [46]	valid_0's auc: 0.986002
# [47]	valid_0's auc: 0.986188
# [48]	valid_0's auc: 0.986239
# [49]	valid_0's auc: 0.986506
# [50]	valid_0's auc: 0.986709
# [51]	valid_0's auc: 0.986861
# [52]	valid_0's auc: 0.987028
# [53]	valid_0's auc: 0.987255
# [54]	valid_0's auc: 0.987389
# [55]	valid_0's auc: 0.987522
# [56]	valid_0's auc: 0.987705
# [57]	valid_0's auc: 0.987787
# [58]	valid_0's auc: 0.98784
# [59]	valid_0's auc: 0.987973
# [60]	valid_0's auc: 0.988078
# [61]	valid_0's auc: 0.988298
# [62]	valid_0's auc: 0.988321
# [63]	valid_0's auc: 0.988527
# [64]	valid_0's auc: 0.988621
# [65]	valid_0's auc: 0.988717
# [66]	valid_0's auc: 0.988739
# [67]	valid_0's auc: 0.988865
# [68]	valid_0's auc: 0.988959
# [69]	valid_0's auc: 0.989025
# [70]	valid_0's auc: 0.98915
# [71]	valid_0's auc: 0.989153
# [72]	valid_0's auc: 0.989235
# [73]	valid_0's auc: 0.989309
# [74]	valid_0's auc: 0.989375
# [75]	valid_0's auc: 0.989442
# [76]	valid_0's auc: 0.989557
# [77]	valid_0's auc: 0.989647
# [78]	valid_0's auc: 0.989648
# [79]	valid_0's auc: 0.9897
# [80]	valid_0's auc: 0.98982
# [81]	valid_0's auc: 0.989904
# [82]	valid_0's auc: 0.989972
# [83]	valid_0's auc: 0.989978
# [84]	valid_0's auc: 0.989994
# [85]	valid_0's auc: 0.990072
# [86]	valid_0's auc: 0.990127
# [87]	valid_0's auc: 0.990162
# [88]	valid_0's auc: 0.990234
# [89]	valid_0's auc: 0.990272
# [90]	valid_0's auc: 0.990274
# [91]	valid_0's auc: 0.990342
# [92]	valid_0's auc: 0.990429
# [93]	valid_0's auc: 0.990504
# [94]	valid_0's auc: 0.990545
# [95]	valid_0's auc: 0.990588
# [96]	valid_0's auc: 0.990629
# [97]	valid_0's auc: 0.990677
# [98]	valid_0's auc: 0.990734
# [99]	valid_0's auc: 0.990808
# [100]	valid_0's auc: 0.990835
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990835
# {  'auc': {  'trn': [0.96313977015192065, 0.96533006032238577],
#              'val': [0.96295505842297879, 0.96542476142895206]}}
#
# Training fold
# [1]	valid_0's auc: 0.847204
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.870496
# [3]	valid_0's auc: 0.884151
# [4]	valid_0's auc: 0.889384
# [5]	valid_0's auc: 0.89045
# [6]	valid_0's auc: 0.896179
# [7]	valid_0's auc: 0.89962
# [8]	valid_0's auc: 0.90251
# [9]	valid_0's auc: 0.906069
# [10]	valid_0's auc: 0.917823
# [11]	valid_0's auc: 0.929253
# [12]	valid_0's auc: 0.936101
# [13]	valid_0's auc: 0.939355
# [14]	valid_0's auc: 0.942533
# [15]	valid_0's auc: 0.954824
# [16]	valid_0's auc: 0.963859
# [17]	valid_0's auc: 0.966741
# [18]	valid_0's auc: 0.967862
# [19]	valid_0's auc: 0.969161
# [20]	valid_0's auc: 0.970398
# [21]	valid_0's auc: 0.971041
# [22]	valid_0's auc: 0.972841
# [23]	valid_0's auc: 0.973751
# [24]	valid_0's auc: 0.97432
# [25]	valid_0's auc: 0.975843
# [26]	valid_0's auc: 0.976423
# [27]	valid_0's auc: 0.977113
# [28]	valid_0's auc: 0.978416
# [29]	valid_0's auc: 0.978987
# [30]	valid_0's auc: 0.980274
# [31]	valid_0's auc: 0.981259
# [32]	valid_0's auc: 0.982025
# [33]	valid_0's auc: 0.98244
# [34]	valid_0's auc: 0.982823
# [35]	valid_0's auc: 0.983288
# [36]	valid_0's auc: 0.983593
# [37]	valid_0's auc: 0.984088
# [38]	valid_0's auc: 0.984471
# [39]	valid_0's auc: 0.984726
# [40]	valid_0's auc: 0.984867
# [41]	valid_0's auc: 0.985188
# [42]	valid_0's auc: 0.985387
# [43]	valid_0's auc: 0.985469
# [44]	valid_0's auc: 0.985895
# [45]	valid_0's auc: 0.986134
# [46]	valid_0's auc: 0.986409
# [47]	valid_0's auc: 0.986672
# [48]	valid_0's auc: 0.986744
# [49]	valid_0's auc: 0.986899
# [50]	valid_0's auc: 0.987107
# [51]	valid_0's auc: 0.987316
# [52]	valid_0's auc: 0.987422
# [53]	valid_0's auc: 0.987571
# [54]	valid_0's auc: 0.987802
# [55]	valid_0's auc: 0.987955
# [56]	valid_0's auc: 0.988123
# [57]	valid_0's auc: 0.988227
# [58]	valid_0's auc: 0.988373
# [59]	valid_0's auc: 0.988397
# [60]	valid_0's auc: 0.988517
# [61]	valid_0's auc: 0.988681
# [62]	valid_0's auc: 0.988816
# [63]	valid_0's auc: 0.988897
# [64]	valid_0's auc: 0.988994
# [65]	valid_0's auc: 0.989001
# [66]	valid_0's auc: 0.989194
# [67]	valid_0's auc: 0.989298
# [68]	valid_0's auc: 0.989275
# [69]	valid_0's auc: 0.989359
# [70]	valid_0's auc: 0.989454
# [71]	valid_0's auc: 0.989526
# [72]	valid_0's auc: 0.989605
# [73]	valid_0's auc: 0.989674
# [74]	valid_0's auc: 0.989764
# [75]	valid_0's auc: 0.989868
# [76]	valid_0's auc: 0.989967
# [77]	valid_0's auc: 0.989967
# [78]	valid_0's auc: 0.990079
# [79]	valid_0's auc: 0.990154
# [80]	valid_0's auc: 0.990206
# [81]	valid_0's auc: 0.990203
# [82]	valid_0's auc: 0.990267
# [83]	valid_0's auc: 0.990322
# [84]	valid_0's auc: 0.990476
# [85]	valid_0's auc: 0.990516
# [86]	valid_0's auc: 0.990547
# [87]	valid_0's auc: 0.990601
# [88]	valid_0's auc: 0.990661
# [89]	valid_0's auc: 0.990703
# [90]	valid_0's auc: 0.990702
# [91]	valid_0's auc: 0.990745
# [92]	valid_0's auc: 0.990798
# [93]	valid_0's auc: 0.990866
# [94]	valid_0's auc: 0.990915
# [95]	valid_0's auc: 0.990986
# [96]	valid_0's auc: 0.99105
# [97]	valid_0's auc: 0.991066
# [98]	valid_0's auc: 0.991115
# [99]	valid_0's auc: 0.991148
# [100]	valid_0's auc: 0.991177
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.991177
# {  'auc': {  'trn': [  0.96313977015192065,
#                        0.96533006032238577,
#                        0.96588130335749933],
#              'val': [  0.96295505842297879,
#                        0.96542476142895206,
#                        0.96587982767841818]}}
#
# Training fold
# [1]	valid_0's auc: 0.844411
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.869191
# [3]	valid_0's auc: 0.872598
# [4]	valid_0's auc: 0.882038
# [5]	valid_0's auc: 0.882525
# [6]	valid_0's auc: 0.897481
# [7]	valid_0's auc: 0.903915
# [8]	valid_0's auc: 0.909875
# [9]	valid_0's auc: 0.913713
# [10]	valid_0's auc: 0.917196
# [11]	valid_0's auc: 0.920099
# [12]	valid_0's auc: 0.943347
# [13]	valid_0's auc: 0.954413
# [14]	valid_0's auc: 0.959065
# [15]	valid_0's auc: 0.96049
# [16]	valid_0's auc: 0.962695
# [17]	valid_0's auc: 0.964454
# [18]	valid_0's auc: 0.965911
# [19]	valid_0's auc: 0.967497
# [20]	valid_0's auc: 0.968417
# [21]	valid_0's auc: 0.969264
# [22]	valid_0's auc: 0.971506
# [23]	valid_0's auc: 0.972218
# [24]	valid_0's auc: 0.972742
# [25]	valid_0's auc: 0.973452
# [26]	valid_0's auc: 0.973849
# [27]	valid_0's auc: 0.974504
# [28]	valid_0's auc: 0.975815
# [29]	valid_0's auc: 0.976374
# [30]	valid_0's auc: 0.977043
# [31]	valid_0's auc: 0.977629
# [32]	valid_0's auc: 0.978696
# [33]	valid_0's auc: 0.979771
# [34]	valid_0's auc: 0.98011
# [35]	valid_0's auc: 0.980638
# [36]	valid_0's auc: 0.980969
# [37]	valid_0's auc: 0.981522
# [38]	valid_0's auc: 0.982007
# [39]	valid_0's auc: 0.982728
# [40]	valid_0's auc: 0.983214
# [41]	valid_0's auc: 0.983429
# [42]	valid_0's auc: 0.983903
# [43]	valid_0's auc: 0.984313
# [44]	valid_0's auc: 0.984585
# [45]	valid_0's auc: 0.984908
# [46]	valid_0's auc: 0.985193
# [47]	valid_0's auc: 0.985539
# [48]	valid_0's auc: 0.985649
# [49]	valid_0's auc: 0.985901
# [50]	valid_0's auc: 0.986283
# [51]	valid_0's auc: 0.986413
# [52]	valid_0's auc: 0.986452
# [53]	valid_0's auc: 0.986691
# [54]	valid_0's auc: 0.986895
# [55]	valid_0's auc: 0.987128
# [56]	valid_0's auc: 0.987274
# [57]	valid_0's auc: 0.987408
# [58]	valid_0's auc: 0.987532
# [59]	valid_0's auc: 0.987733
# [60]	valid_0's auc: 0.987784
# [61]	valid_0's auc: 0.98795
# [62]	valid_0's auc: 0.98807
# [63]	valid_0's auc: 0.988205
# [64]	valid_0's auc: 0.988322
# [65]	valid_0's auc: 0.98844
# [66]	valid_0's auc: 0.98852
# [67]	valid_0's auc: 0.988584
# [68]	valid_0's auc: 0.98863
# [69]	valid_0's auc: 0.988701
# [70]	valid_0's auc: 0.988784
# [71]	valid_0's auc: 0.988759
# [72]	valid_0's auc: 0.988815
# [73]	valid_0's auc: 0.988887
# [74]	valid_0's auc: 0.988909
# [75]	valid_0's auc: 0.989018
# [76]	valid_0's auc: 0.989054
# [77]	valid_0's auc: 0.989036
# [78]	valid_0's auc: 0.989124
# [79]	valid_0's auc: 0.989217
# [80]	valid_0's auc: 0.989282
# [81]	valid_0's auc: 0.989302
# [82]	valid_0's auc: 0.989263
# [83]	valid_0's auc: 0.989363
# [84]	valid_0's auc: 0.989464
# [85]	valid_0's auc: 0.989565
# [86]	valid_0's auc: 0.989606
# [87]	valid_0's auc: 0.989684
# [88]	valid_0's auc: 0.989744
# [89]	valid_0's auc: 0.989829
# [90]	valid_0's auc: 0.989942
# [91]	valid_0's auc: 0.990054
# [92]	valid_0's auc: 0.990107
# [93]	valid_0's auc: 0.990148
# [94]	valid_0's auc: 0.990219
# [95]	valid_0's auc: 0.990268
# [96]	valid_0's auc: 0.990308
# [97]	valid_0's auc: 0.990383
# [98]	valid_0's auc: 0.990432
# [99]	valid_0's auc: 0.990559
# [100]	valid_0's auc: 0.990583
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990583
# {  'auc': {  'trn': [  0.96313977015192065,
#                        0.96533006032238577,
#                        0.96588130335749933,
#                        0.96321212118805721],
#              'val': [  0.96295505842297879,
#                        0.96542476142895206,
#                        0.96587982767841818,
#                        0.96334253073943099]}}
#
# Training fold
# [1]	valid_0's auc: 0.844552
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.869751
# [3]	valid_0's auc: 0.877929
# [4]	valid_0's auc: 0.885773
# [5]	valid_0's auc: 0.886833
# [6]	valid_0's auc: 0.897131
# [7]	valid_0's auc: 0.908372
# [8]	valid_0's auc: 0.914141
# [9]	valid_0's auc: 0.916757
# [10]	valid_0's auc: 0.923607
# [11]	valid_0's auc: 0.936581
# [12]	valid_0's auc: 0.938274
# [13]	valid_0's auc: 0.951734
# [14]	valid_0's auc: 0.960783
# [15]	valid_0's auc: 0.96088
# [16]	valid_0's auc: 0.964094
# [17]	valid_0's auc: 0.965076
# [18]	valid_0's auc: 0.96775
# [19]	valid_0's auc: 0.969264
# [20]	valid_0's auc: 0.970967
# [21]	valid_0's auc: 0.972204
# [22]	valid_0's auc: 0.972612
# [23]	valid_0's auc: 0.973248
# [24]	valid_0's auc: 0.97484
# [25]	valid_0's auc: 0.975554
# [26]	valid_0's auc: 0.976197
# [27]	valid_0's auc: 0.976771
# [28]	valid_0's auc: 0.977315
# [29]	valid_0's auc: 0.97777
# [30]	valid_0's auc: 0.978316
# [31]	valid_0's auc: 0.979382
# [32]	valid_0's auc: 0.980401
# [33]	valid_0's auc: 0.980884
# [34]	valid_0's auc: 0.981429
# [35]	valid_0's auc: 0.982051
# [36]	valid_0's auc: 0.982783
# [37]	valid_0's auc: 0.983137
# [38]	valid_0's auc: 0.983321
# [39]	valid_0's auc: 0.983829
# [40]	valid_0's auc: 0.984116
# [41]	valid_0's auc: 0.984586
# [42]	valid_0's auc: 0.984896
# [43]	valid_0's auc: 0.985131
# [44]	valid_0's auc: 0.985399
# [45]	valid_0's auc: 0.985814
# [46]	valid_0's auc: 0.986089
# [47]	valid_0's auc: 0.98626
# [48]	valid_0's auc: 0.986613
# [49]	valid_0's auc: 0.98674
# [50]	valid_0's auc: 0.98695
# [51]	valid_0's auc: 0.98722
# [52]	valid_0's auc: 0.98736
# [53]	valid_0's auc: 0.987464
# [54]	valid_0's auc: 0.987612
# [55]	valid_0's auc: 0.987754
# [56]	valid_0's auc: 0.987835
# [57]	valid_0's auc: 0.987992
# [58]	valid_0's auc: 0.988083
# [59]	valid_0's auc: 0.988208
# [60]	valid_0's auc: 0.988408
# [61]	valid_0's auc: 0.988453
# [62]	valid_0's auc: 0.988551
# [63]	valid_0's auc: 0.988602
# [64]	valid_0's auc: 0.988644
# [65]	valid_0's auc: 0.988797
# [66]	valid_0's auc: 0.988935
# [67]	valid_0's auc: 0.989065
# [68]	valid_0's auc: 0.989153
# [69]	valid_0's auc: 0.989218
# [70]	valid_0's auc: 0.989378
# [71]	valid_0's auc: 0.989395
# [72]	valid_0's auc: 0.989444
# [73]	valid_0's auc: 0.989437
# [74]	valid_0's auc: 0.989571
# [75]	valid_0's auc: 0.989657
# [76]	valid_0's auc: 0.989729
# [77]	valid_0's auc: 0.989786
# [78]	valid_0's auc: 0.989837
# [79]	valid_0's auc: 0.989831
# [80]	valid_0's auc: 0.989954
# [81]	valid_0's auc: 0.990028
# [82]	valid_0's auc: 0.990131
# [83]	valid_0's auc: 0.990166
# [84]	valid_0's auc: 0.990219
# [85]	valid_0's auc: 0.990189
# [86]	valid_0's auc: 0.990257
# [87]	valid_0's auc: 0.990316
# [88]	valid_0's auc: 0.990377
# [89]	valid_0's auc: 0.990412
# [90]	valid_0's auc: 0.990451
# [91]	valid_0's auc: 0.990507
# [92]	valid_0's auc: 0.990562
# [93]	valid_0's auc: 0.990553
# [94]	valid_0's auc: 0.990589
# [95]	valid_0's auc: 0.990636
# [96]	valid_0's auc: 0.990785
# [97]	valid_0's auc: 0.990836
# [98]	valid_0's auc: 0.990868
# [99]	valid_0's auc: 0.990891
# [100]	valid_0's auc: 0.990924
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990924
# {  'auc': {  'trn': [  0.96313977015192065,
#                        0.96533006032238577,
#                        0.96588130335749933,
#                        0.96321212118805721,
#                        0.96479517093915712],
#              'val': [  0.96295505842297879,
#                        0.96542476142895206,
#                        0.96587982767841818,
#                        0.96334253073943099,
#                        0.96460152475352057]}}
#
# {'trn_auc_mean': 0.96447168519180404, 'val_auc_mean': 0.96444074060466023}
# CPU times: user 31min 11s, sys: 52 s, total: 32min 3s
# Wall time: 3min 9s

# %%
results
# Out:
#          dataset           model   params    time  trn_auc_mean  trn_auc_std  \
# 0  metadata-only  LGBMClassifier  default  189.22      0.964472     0.001113
#
#    val_auc_mean  val_auc_std
# 0      0.964441     0.001138

# %%
test[target_col] = y_test

# %% [markdown]
# # Submission

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission = pd.merge(submission[['PredictionIdx']], test[['PredictionIdx', target_col]], how='left', on='PredictionIdx')

# %%
submission[target_col].value_counts().sort_index()
# Out:
# 0.0      5412
# 0.2       544
# 0.4       498
# 0.6       703
# 0.8      1813
# 1.0    475788
# Name: CustomerInterest, dtype: int64

# %%
submission.head()
# Out:
#   PredictionIdx  CustomerInterest
# 0    a1e0d80784               1.0
# 1    c2cc6cc2a8               1.0
# 2    a8e94f6344               1.0
# 3    758bae1e35               1.0
# 4    02ab378ee8               1.0

# %%
submission.to_csv('lgbm_metadata.csv', index=False)
