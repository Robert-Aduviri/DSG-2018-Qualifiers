# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os, math
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from pandas_summary import DataFrameSummary
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 400)
sns.set()

os.chdir('../..')
from src import utils

# %%
DATA        = Path('data')
RAW         = DATA/'raw'
INTERIM     = DATA/'interim'
PROCESSED   = DATA/'processed'
SUBMISSIONS = DATA/'submissions'

# %%
challenge  = pd.read_csv(RAW/'Challenge_20180423.csv', low_memory=False)
customer   = pd.read_csv(RAW/'Customer.csv', low_memory=False)
isin       = pd.read_csv(RAW/'Isin.csv', low_memory=False)
market     = pd.read_csv(RAW/'Market.csv', low_memory=False)
macro      = pd.read_csv(RAW/'MarketData_Macro.csv', low_memory=False)
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
trade      = pd.read_csv(RAW/'Trade.csv', low_memory=False)

# %% [markdown]
# ## 50% baseline

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission['CustomerInterest'] = 0.5

# %%
submission.head()
# Out:
#   PredictionIdx  CustomerInterest
# 0    a1e0d80784               0.5
# 1    c2cc6cc2a8               0.5
# 2    a8e94f6344               0.5
# 3    758bae1e35               0.5
# 4    02ab378ee8               0.5

# %%
submission.to_csv(SUBMISSIONS/'baseline50.csv', index=False)

# %% [markdown]
# ## 0 baseline

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission['CustomerInterest'] = 0
submission.to_csv(SUBMISSIONS/'baseline0.csv', index=False)

# %% [markdown]
# ## 1 baseline

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission['CustomerInterest'] = 1
submission.to_csv(SUBMISSIONS/'baseline100.csv', index=False)

# %% [markdown]
# ## Metadata only

# %%
train = pd.merge(trade, customer, how='left', on='CustomerIdx')
train = pd.merge(train, isin, how='left', on='IsinIdx')

# %%
test = pd.merge(challenge, customer, how='left', on='CustomerIdx')
test = pd.merge(test, isin, how='left', on='IsinIdx')

# %%
print(train.shape)
train.head(3)
# Out:
# (6762021, 28)
#    TradeDateKey  CustomerIdx  IsinIdx BuySell  NotionalEUR  Price TradeStatus  \
# 0      20161207         2789     8478    Sell     653168.0    0.0     Unknown
# 1      20170329         2574    14562     Buy    1656487.0    0.0     Unknown
# 2      20170418         2574     4747     Buy     939673.0    0.0     Unknown
#
#    CustomerInterest                        Sector                  Subsector  \
# 0               1.0  Asset Managers & Hedge Funds                 Hedge Fund
# 1               1.0  Asset Managers & Hedge Funds  Independent Asset Manager
# 2               1.0  Asset Managers & Hedge Funds  Independent Asset Manager
#
#    Region_x Country  TickerIdx  ActualMaturityDateKey  IssueDateKey Seniority  \
# 0  Americas     USA       1173               20250201      20150127       SEN
# 1  Americas     USA       3216               20260615      20161014       SEN
# 2  Americas     USA        152               20190127      20140127       SEN
#
#   Currency ActivityGroup  Region_y    Activity RiskCaptain            Owner  \
# 0      USD      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY     US HY PHARMA
# 1      USD      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY     US HY PHARMA
# 2      USD      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY  US HY FIN AUTOS
#
#   CompositeRating        IndustrySector    IndustrySubgroup     MarketIssue  \
# 0            CCC+  Consumer, Non-cyclic       Medical-Drugs  Priv placement
# 1             BB-    Consumer, Cyclical    Home Furnishings          Global
# 2              BB             Financial  Finance-Auto Loans          Global
#
#    IssuedAmount CouponType
# 0  1.200000e+09   STEP CPN
# 1  6.000000e+08      FIXED
# 2  7.500000e+08      FIXED

# %%
print(test.shape)
test.head(3)
# Out:
# (484758, 26)
#   PredictionIdx   DateKey  CustomerIdx  IsinIdx BuySell  CustomerInterest  \
# 0    a1e0d80784  20180423         1856    13323     Buy               NaN
# 1    c2cc6cc2a8  20180423         1856     9230     Buy               NaN
# 2    a8e94f6344  20180423         1780     9157     Buy               NaN
#
#                          Sector                       Subsector  Region_x  \
# 0  Asset Managers & Hedge Funds       Independent Asset Manager  Americas
# 1  Asset Managers & Hedge Funds       Independent Asset Manager  Americas
# 2  Asset Managers & Hedge Funds  Asset Mgr owned by Bank/Insur.  Americas
#
#   Country  TickerIdx  ActualMaturityDateKey  IssueDateKey Seniority Currency  \
# 0     USA       2740               20210315      20130314       SEN      USD
# 1     USA       1446               20240215      20131210       SEN      USD
# 2     USA       1387               20360815      20060815       SEN      USD
#
#   ActivityGroup  Region_y    Activity  RiskCaptain              Owner  \
# 0      FLOW G10  AMERICAS  CDS AND HY   CDS AND HY         US TMT CDS
# 1      FLOW G10  AMERICAS  CDS AND HY   CDS AND HY    US HY FIN AUTOS
# 2      FLOW G10  AMERICAS     HG CASH  HG CASH FIN  US FIN SHORT CASH
#
#   CompositeRating        IndustrySector         IndustrySubgroup  \
# 0              B-  Consumer, Non-cyclic      Printing-Commercial
# 1               B             Financial     Multi-line Insurance
# 2              A+            Industrial  Diversified Manufact Op
#
#     MarketIssue  IssuedAmount CouponType
# 0        Global   450000000.0      FIXED
# 1   US domestic   400000000.0      FIXED
# 2  Domestic mtn   300000000.0   FLOATING

# %%
# same date column name
train['DateKey'] = train['TradeDateKey']
train.drop('TradeDateKey', axis=1, inplace=True)

# %%
# drop extra columns 
extra_cols = ['Price', 'TradeStatus', 'NotionalEUR']
train.drop(extra_cols, axis=1, inplace=True)

# %%
# PredictionIdx remains in test
train.shape, test.shape
# Out:
# ((6762021, 25), (484758, 26))

# %%
# train - test, test - train
set(train.columns).difference(test.columns), set(test.columns).difference(train.columns)
# Out:
# (set(), {'PredictionIdx'})

# %%
# keep same column order
cols = list(train.columns)
test = test[cols + ['PredictionIdx']].copy()

# %%
train.head(3)
# Out:
#    CustomerIdx  IsinIdx BuySell  CustomerInterest  \
# 0         2789     8478    Sell               1.0
# 1         2574    14562     Buy               1.0
# 2         2574     4747     Buy               1.0
#
#                          Sector                  Subsector  Region_x Country  \
# 0  Asset Managers & Hedge Funds                 Hedge Fund  Americas     USA
# 1  Asset Managers & Hedge Funds  Independent Asset Manager  Americas     USA
# 2  Asset Managers & Hedge Funds  Independent Asset Manager  Americas     USA
#
#    TickerIdx  ActualMaturityDateKey  IssueDateKey Seniority Currency  \
# 0       1173               20250201      20150127       SEN      USD
# 1       3216               20260615      20161014       SEN      USD
# 2        152               20190127      20140127       SEN      USD
#
#   ActivityGroup  Region_y    Activity RiskCaptain            Owner  \
# 0      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY     US HY PHARMA
# 1      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY     US HY PHARMA
# 2      FLOW G10  AMERICAS  CDS AND HY  CDS AND HY  US HY FIN AUTOS
#
#   CompositeRating        IndustrySector    IndustrySubgroup     MarketIssue  \
# 0            CCC+  Consumer, Non-cyclic       Medical-Drugs  Priv placement
# 1             BB-    Consumer, Cyclical    Home Furnishings          Global
# 2              BB             Financial  Finance-Auto Loans          Global
#
#    IssuedAmount CouponType   DateKey
# 0  1.200000e+09   STEP CPN  20161207
# 1  6.000000e+08      FIXED  20170329
# 2  7.500000e+08      FIXED  20170418

# %%
test.head(3)
# Out:
#    CustomerIdx  IsinIdx BuySell  CustomerInterest  \
# 0         1856    13323     Buy               NaN
# 1         1856     9230     Buy               NaN
# 2         1780     9157     Buy               NaN
#
#                          Sector                       Subsector  Region_x  \
# 0  Asset Managers & Hedge Funds       Independent Asset Manager  Americas
# 1  Asset Managers & Hedge Funds       Independent Asset Manager  Americas
# 2  Asset Managers & Hedge Funds  Asset Mgr owned by Bank/Insur.  Americas
#
#   Country  TickerIdx  ActualMaturityDateKey  IssueDateKey Seniority Currency  \
# 0     USA       2740               20210315      20130314       SEN      USD
# 1     USA       1446               20240215      20131210       SEN      USD
# 2     USA       1387               20360815      20060815       SEN      USD
#
#   ActivityGroup  Region_y    Activity  RiskCaptain              Owner  \
# 0      FLOW G10  AMERICAS  CDS AND HY   CDS AND HY         US TMT CDS
# 1      FLOW G10  AMERICAS  CDS AND HY   CDS AND HY    US HY FIN AUTOS
# 2      FLOW G10  AMERICAS     HG CASH  HG CASH FIN  US FIN SHORT CASH
#
#   CompositeRating        IndustrySector         IndustrySubgroup  \
# 0              B-  Consumer, Non-cyclic      Printing-Commercial
# 1               B             Financial     Multi-line Insurance
# 2              A+            Industrial  Diversified Manufact Op
#
#     MarketIssue  IssuedAmount CouponType   DateKey PredictionIdx
# 0        Global   450000000.0      FIXED  20180423    a1e0d80784
# 1   US domestic   400000000.0      FIXED  20180423    c2cc6cc2a8
# 2  Domestic mtn   300000000.0   FLOATING  20180423    a8e94f6344

# %%
# Heuristic for num columns
id_cols = ['CustomerIdx', 'IsinIdx']
target_col = 'CustomerInterest'
num_cols = [c for c in train._get_numeric_data().columns if c not in id_cols + [target_col, 'TickerIdx']]
cat_cols = [c for c in train.columns if c not in id_cols + num_cols + [target_col]]

# %%
num_cols
# Out:
# ['ActualMaturityDateKey', 'IssueDateKey', 'IssuedAmount', 'DateKey']

# %%
print(cat_cols)
# Out:
# ['BuySell', 'Sector', 'Subsector', 'Region_x', 'Country', 'TickerIdx', 'Seniority', 'Currency', 'ActivityGroup', 'Region_y', 'Activity', 'RiskCaptain', 'Owner', 'CompositeRating', 'IndustrySector', 'IndustrySubgroup', 'MarketIssue', 'CouponType']

# %%
for col in cat_cols:
    print(train[col].nunique(), '\t', col)
# Out:
# 2 	 BuySell
# 5 	 Sector
# 41 	 Subsector
# 3 	 Region_x
# 99 	 Country
# 3543 	 TickerIdx
# 9 	 Seniority
# 23 	 Currency
# 3 	 ActivityGroup
# 8 	 Region_y
# 16 	 Activity
# 38 	 RiskCaptain
# 105 	 Owner
# 29 	 CompositeRating
# 13 	 IndustrySector
# 338 	 IndustrySubgroup
# 14 	 MarketIssue
# 6 	 CouponType

# %%
train[target_col].value_counts()
# Out:
# 0.0    4550092
# 1.0    2211929
# Name: CustomerInterest, dtype: int64

# %%
train.shape, test.shape
# Out:
# ((6762021, 25), (484758, 26))

# %%
train.drop(id_cols + [target_col], axis=1).columns
# Out:
# Index(['BuySell', 'Sector', 'Subsector', 'Region_x', 'Country', 'TickerIdx',
#        'ActualMaturityDateKey', 'IssueDateKey', 'Seniority', 'Currency',
#        'ActivityGroup', 'Region_y', 'Activity', 'RiskCaptain', 'Owner',
#        'CompositeRating', 'IndustrySector', 'IndustrySubgroup', 'MarketIssue',
#        'IssuedAmount', 'CouponType', 'DateKey'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing

# %%
from src.utils import apply_cats
for col in cat_cols:
    train[col] = train[col].astype('category').cat.as_ordered()
apply_cats(test, train)

# %%
for col in cat_cols:
    train[col] = train[col].cat.codes
    test[col] = test[col].cat.codes

# %% [markdown]
# ## Cross validation

# %%
import time, pprint
from sklearn.model_selection import KFold

kfolds = KFold(n_splits=5, shuffle=True, random_state=42)
pp = pprint.PrettyPrinter(indent=3)

# %%
from sklearn.metrics import roc_auc_score

# globals: [cat_indices]
def fit_model(model, model_name, X_trn, y_trn, X_val, y_val):
    if model_name in ['XGBClassifier', 'LGBMClassifier']:
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  early_stopping_rounds=30,
                  eval_metric='auc')
    elif model_name == 'CatBoostClassifier':
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  use_best_model=True,
                  cat_features=cat_indices)
    else:
        model.fit(X_trn, y_trn)
        
def calculate_metrics(model, metrics, X_trn, y_trn, X_val, y_val):
    metric_function = {'auc': roc_auc_score}
    dset = {'trn': {'X': X_trn, 'y': y_trn},
            'val': {'X': X_val, 'y': y_val}}
    
    for d in dset:
        y_pred = model.predict_proba(dset[d]['X'])[:,1]
        for m in metrics:
            metrics[m][d] += [metric_function[m](dset[d]['y'], y_pred)]
                
    pp.pprint(metrics)
    print()

# %%
# globals: [kfolds]
def run_model(model, X, y, X_test, metric_names, results=None, dataset_desc='', params_desc=''):
    model_name = str(model.__class__).split('.')[-1].replace('>','').replace("'",'')
    print(model_name, '\n')
    if results is None: results = pd.DataFrame()
    metrics = {metric: {'trn': [], 'val': []} for metric in metric_names}
    y_test = np.zeros((len(X_test)))
    start = time.time()
    for trn_idx, val_idx in kfolds.split(X, y):
        print('Training fold')
        fit_model(model, model_name, 
                          X.iloc[trn_idx], y.iloc[trn_idx],
                          X.iloc[val_idx], y.iloc[val_idx])
        calculate_metrics(model, metrics, 
                          X.iloc[trn_idx], y.iloc[trn_idx],
                          X.iloc[val_idx], y.iloc[val_idx])
        y_test += model.predict_proba(X_test)[:,1]
    y_test /= kfolds.n_splits
    end = time.time()
    means = {f'{d}_{m}_mean': np.mean(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    stds  = {f'{d}_{m}_std': np.std(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    metadata = {'model': model_name, 'dataset': dataset_desc,
                'params': params_desc, 'time': round(end - start, 2)}
    pp.pprint(means)
    results = results.append(pd.Series({**metadata, **means, **stds}), ignore_index=True)
    return y_test, metrics, results

# %%
from lightgbm import LGBMClassifier

# %%
metric_names = ['auc']

# %%
# %%time
y_test, metrics, results = run_model(
                            LGBMClassifier(),
                            train.drop(id_cols + [target_col], axis=1),
                            train[target_col],
                            test.drop(id_cols + [target_col, 'PredictionIdx'], axis=1),
                            metric_names, None, 
                            params_desc='default',
                            dataset_desc='metadata-only')
# Out:
# LGBMClassifier
#
# Training fold
# [1]	valid_0's auc: 0.850361
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.869478
# [3]	valid_0's auc: 0.872868
# [4]	valid_0's auc: 0.87765
# [5]	valid_0's auc: 0.891636
# [6]	valid_0's auc: 0.896225
# [7]	valid_0's auc: 0.898164
# [8]	valid_0's auc: 0.907492
# [9]	valid_0's auc: 0.909081
# [10]	valid_0's auc: 0.914509
# [11]	valid_0's auc: 0.922819
# [12]	valid_0's auc: 0.929132
# [13]	valid_0's auc: 0.929643
# [14]	valid_0's auc: 0.945129
# [15]	valid_0's auc: 0.95476
# [16]	valid_0's auc: 0.95848
# [17]	valid_0's auc: 0.959579
# [18]	valid_0's auc: 0.962591
# [19]	valid_0's auc: 0.964839
# [20]	valid_0's auc: 0.965932
# [21]	valid_0's auc: 0.967053
# [22]	valid_0's auc: 0.96842
# [23]	valid_0's auc: 0.969173
# [24]	valid_0's auc: 0.970089
# [25]	valid_0's auc: 0.971384
# [26]	valid_0's auc: 0.971915
# [27]	valid_0's auc: 0.972695
# [28]	valid_0's auc: 0.973429
# [29]	valid_0's auc: 0.974465
# [30]	valid_0's auc: 0.975193
# [31]	valid_0's auc: 0.975932
# [32]	valid_0's auc: 0.976474
# [33]	valid_0's auc: 0.977339
# [34]	valid_0's auc: 0.978032
# [35]	valid_0's auc: 0.978587
# [36]	valid_0's auc: 0.978892
# [37]	valid_0's auc: 0.979365
# [38]	valid_0's auc: 0.979739
# [39]	valid_0's auc: 0.980235
# [40]	valid_0's auc: 0.980507
# [41]	valid_0's auc: 0.980762
# [42]	valid_0's auc: 0.981166
# [43]	valid_0's auc: 0.981367
# [44]	valid_0's auc: 0.981621
# [45]	valid_0's auc: 0.981899
# [46]	valid_0's auc: 0.982203
# [47]	valid_0's auc: 0.982378
# [48]	valid_0's auc: 0.982498
# [49]	valid_0's auc: 0.98267
# [50]	valid_0's auc: 0.982877
# [51]	valid_0's auc: 0.983045
# [52]	valid_0's auc: 0.983242
# [53]	valid_0's auc: 0.983455
# [54]	valid_0's auc: 0.983562
# [55]	valid_0's auc: 0.983684
# [56]	valid_0's auc: 0.983792
# [57]	valid_0's auc: 0.98383
# [58]	valid_0's auc: 0.983977
# [59]	valid_0's auc: 0.984145
# [60]	valid_0's auc: 0.984279
# [61]	valid_0's auc: 0.984256
# [62]	valid_0's auc: 0.984419
# [63]	valid_0's auc: 0.984531
# [64]	valid_0's auc: 0.984659
# [65]	valid_0's auc: 0.984793
# [67]	valid_0's auc: 0.985951
# [68]	valid_0's auc: 0.986065
# [69]	valid_0's auc: 0.986159
# [70]	valid_0's auc: 0.986212
# [71]	valid_0's auc: 0.986197
# [72]	valid_0's auc: 0.986264
# [73]	valid_0's auc: 0.986387
# [74]	valid_0's auc: 0.986435
# [75]	valid_0's auc: 0.986536
# [76]	valid_0's auc: 0.986604
# [77]	valid_0's auc: 0.986581
# [78]	valid_0's auc: 0.986662
# [79]	valid_0's auc: 0.986747
# [80]	valid_0's auc: 0.986793
# [81]	valid_0's auc: 0.986881
# [82]	valid_0's auc: 0.986944
# [83]	valid_0's auc: 0.98699
# [84]	valid_0's auc: 0.986972
# [85]	valid_0's auc: 0.987118
# [86]	valid_0's auc: 0.987089
# [87]	valid_0's auc: 0.987136
# [88]	valid_0's auc: 0.987202
# [89]	valid_0's auc: 0.987226
# [90]	valid_0's auc: 0.98728
# [91]	valid_0's auc: 0.987401
# [92]	valid_0's auc: 0.987445
# [93]	valid_0's auc: 0.987551
# [94]	valid_0's auc: 0.987562
# [95]	valid_0's auc: 0.987606
# [96]	valid_0's auc: 0.987628
# [97]	valid_0's auc: 0.987705
# [98]	valid_0's auc: 0.987787
# [99]	valid_0's auc: 0.987824
# [100]	valid_0's auc: 0.987858
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.987858
# {  'auc': {  'trn': [  0.9871836196777911,
#                        0.9881754521080053,
#                        0.9881143996646106,
#                        0.9869924830962798,
#                        0.9880114115224863],
#              'val': [  0.9871668836214289,
#                        0.9881370727231914,
#                        0.9881976708223585,
#                        0.9869735034856955,
#                        0.987857556640434]}}
#
# {'trn_auc_mean': 0.9876954732138346, 'val_auc_mean': 0.9876665374586218}
# CPU times: user 27min 14s, sys: 14.5 s, total: 27min 28s
# Wall time: 3min 14s

# %%
results
# Out:
#          dataset           model   params    time  trn_auc_mean  trn_auc_std  \
# 0  metadata-only  LGBMClassifier  default  194.37      0.987695     0.000502
#
#    val_auc_mean  val_auc_std
# 0      0.987667     0.000504

# %%
results
# Out:
#          dataset           model   params    time  trn_auc_mean  trn_auc_std  \
# 0  metadata-only  LGBMClassifier  default  190.01      0.956597     0.001176
#
#    val_auc_mean  val_auc_std
# 0      0.956548     0.001211

# %%
test[target_col] = y_test

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission = pd.merge(submission[['PredictionIdx']], test[['PredictionIdx', target_col]], how='left', on='PredictionIdx')

# %%
submission[target_col].describe()
# Out:
# count    484758.000000
# mean          0.855839
# std           0.136516
# min           0.133469
# 25%           0.799480
# 50%           0.908899
# 75%           0.954256
# max           0.996476
# Name: CustomerInterest, dtype: float64

# %%
submission[target_col].value_counts().sort_index()
# Out:
# 0.0      5994
# 0.2       789
# 0.4      1085
# 0.6      1122
# 0.8      2562
# 1.0    473206
# Name: CustomerInterest, dtype: int64

# %%
submission.head()
# Out:
#   PredictionIdx  CustomerInterest
# 0    a1e0d80784          0.530181
# 1    c2cc6cc2a8          0.572911
# 2    a8e94f6344          0.653898
# 3    758bae1e35          0.835174
# 4    02ab378ee8          0.635883

# %%
submission.to_csv(SUBMISSIONS/'lgbm_metadata_proba.csv', index=False)
