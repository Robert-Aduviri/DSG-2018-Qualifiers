# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os, math
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from pandas_summary import DataFrameSummary
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 400)
sns.set()

os.chdir('../..')
from src import utils

# %%
DATA        = Path('data')
RAW         = DATA/'raw'
INTERIM     = DATA/'interim'
PROCESSED   = DATA/'processed'
SUBMISSIONS = DATA/'submissions'

# %%
challenge  = pd.read_csv(RAW/'Challenge_20180423.csv', low_memory=False)
customer   = pd.read_csv(RAW/'Customer.csv', low_memory=False)
isin       = pd.read_csv(RAW/'Isin.csv', low_memory=False)
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
trade      = pd.read_csv(RAW/'Trade.csv', low_memory=False)

# %%
train = pd.read_feather(PROCESSED/'week_0409_val.feather')
val = pd.read_feather(PROCESSED/'week_0416_val.feather')
test  = pd.read_feather(PROCESSED/'test_datediffs.feather')

# %%
train.head()
# Out:
#    index  TradeDateKey  CustomerIdx  IsinIdx BuySell  CustomerInterest  \
# 0      0      20180409            0    21856     Buy               0.0
# 1      1      20180409            0    21856    Sell               0.0
# 2      2      20180409            0    24944     Buy               0.0
# 3      3      20180409            0    24944    Sell               0.0
# 4      4      20180409            0    25992     Buy               0.0
#
#    DaysSinceBuySell  DaysSinceTransaction  DaysSinceCustomerActivity  \
# 0               282                   282                         27
# 1               282                   282                         27
# 2               282                    28                         27
# 3                28                    28                         27
# 4                41                    41                         27
#
#    DaysSinceBondActivity
# 0                     19
# 1                     19
# 2                     19
# 3                     19
# 4                     13

# %%
test.head()
# Out:
#   PredictionIdx   DateKey  CustomerIdx  IsinIdx BuySell  CustomerInterest  \
# 0    a1e0d80784  20180423         1856    13323     Buy               NaN
# 1    c2cc6cc2a8  20180423         1856     9230     Buy               NaN
# 2    a8e94f6344  20180423         1780     9157     Buy               NaN
# 3    758bae1e35  20180423         2129     9131     Buy               NaN
# 4    02ab378ee8  20180423         1758     7151     Buy               NaN
#
#    TradeDateKey  DaysSinceBuySell  DaysSinceTransaction  \
# 0      20180423               296                   296
# 1      20180423                14                    14
# 2      20180423               296                   296
# 3      20180423               296                   296
# 4      20180423               296                   296
#
#    DaysSinceCustomerActivity  DaysSinceBondActivity
# 0                          3                      3
# 1                          3                      3
# 2                          3                    296
# 3                          3                     11
# 4                          3                     33

# %%
# %%time
from src.utils import add_dayscount
add_dayscount(train, trade[trade.TradeDateKey > 20180000])
add_dayscount(val, trade[trade.TradeDateKey > 20180000])
add_dayscount(test, trade[trade.TradeDateKey > 20180000])

# %%
# %%time
from src.utils import preprocessing_pipeline
train = preprocessing_pipeline(train, customer, isin, trade)
val   = preprocessing_pipeline(val, customer, isin, trade)
test  = preprocessing_pipeline(test, customer, isin, trade)
# Out:
# CPU times: user 860 ms, sys: 180 ms, total: 1.04 s
# Wall time: 1.09 s

# %%
# %%time
train.reset_index().to_feather(PROCESSED/'week_0409_diffscount.feather')
val.reset_index().to_feather(PROCESSED/'week_0416_diffscount.feather')
test.reset_index().to_feather(PROCESSED/'week_0423_diffscount.feather')
# Out:
# CPU times: user 3.46 s, sys: 1.22 s, total: 4.68 s
# Wall time: 4.68 s

# %%
cat_cols = ['BuySell', 'Sector', 'Subsector', 'Region_x', 'Country', 
            'TickerIdx', 'Seniority', 'Currency', 'ActivityGroup', 
            'Region_y', 'Activity', 'RiskCaptain', 'Owner', 'CompositeRating', 
            'IndustrySector', 'IndustrySubgroup', 'MarketIssue', 'CouponType']

# %%
id_cols = ['TradeDateKey', 'CustomerIdx', 'IsinIdx']
target_col = 'CustomerInterest'
pred_col = 'PredictionIdx'

# %%
train.drop('index', axis=1, inplace=True)
val.drop('index', axis=1, inplace=True)
test.drop('DateKey', axis=1, inplace=True)

# %%
train.shape, val.shape, test.shape
# Out:
# ((492906, 33), (493590, 33), (484758, 34))

# %% [markdown]
# ## Preprocessing

# %%
from src.utils import apply_cats
for col in cat_cols:
    test[col] = test[col].astype('category').cat.as_ordered()
apply_cats(train, test)
apply_cats(val, test)

for col in cat_cols:
    train[col] = train[col].cat.codes
    val[col] = val[col].cat.codes
    test[col] = test[col].cat.codes

# %% [markdown]
# ## Model

# %%
import time, pprint
pp = pprint.PrettyPrinter(indent=3)

# %%
from sklearn.metrics import roc_auc_score

# globals: [cat_indices]
def fit_model(model, model_name, X_trn, y_trn, X_val, y_val):
    if model_name in ['XGBClassifier', 'LGBMClassifier']:
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  early_stopping_rounds=30,
                  eval_metric='auc')
    elif model_name == 'CatBoostClassifier':
        model.fit(X_trn, y_trn, 
                  eval_set=[(X_val, y_val)],
                  use_best_model=True,
                  cat_features=cat_indices)
    else:
        model.fit(X_trn, y_trn)
        
def calculate_metrics(model, metrics, X_trn, y_trn, X_val, y_val):
    metric_function = {'auc': roc_auc_score}
    dset = {'trn': {'X': X_trn, 'y': y_trn},
            'val': {'X': X_val, 'y': y_val}}
    
    for d in dset:
        y_pred = model.predict_proba(dset[d]['X'])[:,1]
        for m in metrics:
            metrics[m][d] += [metric_function[m](dset[d]['y'], y_pred)]
                
    pp.pprint(metrics)
    print()

# %%
def run_model(model, X_train, y_train, X_val, y_val, X_test, 
              metric_names, results=None, dataset_desc='', params_desc=''):
    model_name = str(model.__class__).split('.')[-1].replace('>','').replace("'",'')
    print(model_name, '\n')
    if results is None: results = pd.DataFrame()
    metrics = {metric: {'trn': [], 'val': []} for metric in metric_names}
    y_test = np.zeros((len(X_test)))
    start = time.time()
    
    fit_model(model, model_name, X_train, y_train, X_val, y_val)
    calculate_metrics(model, metrics, X_train, y_train, X_val, y_val)
    y_test = model.predict_proba(X_test)[:,1]
            
    end = time.time()
    means = {f'{d}_{m}_mean': np.mean(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    stds  = {f'{d}_{m}_std': np.std(metrics[m][d]) for m in metrics \
                                                     for d in metrics[m]}
    metadata = {'model': model_name, 'dataset': dataset_desc,
                'params': params_desc, 'time': round(end - start, 2)}
    pp.pprint(means)
    results = results.append(pd.Series({**metadata, **means, **stds}), ignore_index=True)
    return y_test, metrics, results, model

# %%
from lightgbm import LGBMClassifier
metric_names = ['auc']

# %%
# %%time
y_test_0409, metrics, results, model = run_model(
            LGBMClassifier(n_estimators=1000),
            train.drop(id_cols + [target_col], axis=1),
            train[target_col],
            val.drop(id_cols + [target_col], axis=1),
            val[target_col],
            test.drop(id_cols + [target_col, pred_col], axis=1),
            metric_names, None, 
            params_desc='n_estimators=1000',
            dataset_desc='week_datediffs')
# Out:
# LGBMClassifier
#
# [1]	valid_0's auc: 0.726659
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.730065
# [3]	valid_0's auc: 0.73239
# [4]	valid_0's auc: 0.745058
# [5]	valid_0's auc: 0.746611
# [6]	valid_0's auc: 0.747184
# [7]	valid_0's auc: 0.748441
# [8]	valid_0's auc: 0.748515
# [9]	valid_0's auc: 0.749002
# [10]	valid_0's auc: 0.750193
# [11]	valid_0's auc: 0.750263
# [12]	valid_0's auc: 0.750629
# [13]	valid_0's auc: 0.750929
# [14]	valid_0's auc: 0.751122
# [15]	valid_0's auc: 0.751986
# [16]	valid_0's auc: 0.752665
# [17]	valid_0's auc: 0.752993
# [18]	valid_0's auc: 0.753173
# [19]	valid_0's auc: 0.753433
# [20]	valid_0's auc: 0.753773
# [21]	valid_0's auc: 0.754055
# [22]	valid_0's auc: 0.755153
# [23]	valid_0's auc: 0.755584
# [24]	valid_0's auc: 0.755423
# [25]	valid_0's auc: 0.757235
# [26]	valid_0's auc: 0.75805
# [27]	valid_0's auc: 0.758561
# [28]	valid_0's auc: 0.758942
# [29]	valid_0's auc: 0.758745
# [30]	valid_0's auc: 0.759008
# [31]	valid_0's auc: 0.759333
# [32]	valid_0's auc: 0.759869
# [33]	valid_0's auc: 0.76022
# [34]	valid_0's auc: 0.760724
# [35]	valid_0's auc: 0.760877
# [36]	valid_0's auc: 0.761028
# [37]	valid_0's auc: 0.761258
# [38]	valid_0's auc: 0.761465
# [39]	valid_0's auc: 0.761569
# [40]	valid_0's auc: 0.761929
# [41]	valid_0's auc: 0.762261
# [42]	valid_0's auc: 0.762444
# [43]	valid_0's auc: 0.762991
# [44]	valid_0's auc: 0.763217
# [45]	valid_0's auc: 0.763269
# [46]	valid_0's auc: 0.763268
# [47]	valid_0's auc: 0.763571
# [48]	valid_0's auc: 0.763938
# [49]	valid_0's auc: 0.764309
# [50]	valid_0's auc: 0.76411
# [51]	valid_0's auc: 0.76436
# [52]	valid_0's auc: 0.764482
# [53]	valid_0's auc: 0.764747
# [54]	valid_0's auc: 0.764602
# [55]	valid_0's auc: 0.765053
# [56]	valid_0's auc: 0.765137
# [57]	valid_0's auc: 0.765237
# [58]	valid_0's auc: 0.765468
# [59]	valid_0's auc: 0.765736
# [60]	valid_0's auc: 0.765746
# [61]	valid_0's auc: 0.765883
# [62]	valid_0's auc: 0.765801
# [63]	valid_0's auc: 0.765944
# [64]	valid_0's auc: 0.766061
# [65]	valid_0's auc: 0.766086
# [66]	valid_0's auc: 0.766146
# [67]	valid_0's auc: 0.766108
# [68]	valid_0's auc: 0.765976
# [69]	valid_0's auc: 0.766372
# [70]	valid_0's auc: 0.766501
# [71]	valid_0's auc: 0.766546
# [72]	valid_0's auc: 0.766694
# [73]	valid_0's auc: 0.766989
# [74]	valid_0's auc: 0.766896
# [75]	valid_0's auc: 0.766909
# [76]	valid_0's auc: 0.767057
# [77]	valid_0's auc: 0.767195
# [78]	valid_0's auc: 0.767191
# [79]	valid_0's auc: 0.767235
# [80]	valid_0's auc: 0.767267
# [81]	valid_0's auc: 0.767399
# [82]	valid_0's auc: 0.76722
# [83]	valid_0's auc: 0.767225
# [84]	valid_0's auc: 0.767377
# [85]	valid_0's auc: 0.767729
# [86]	valid_0's auc: 0.76783
# [87]	valid_0's auc: 0.767782
# [88]	valid_0's auc: 0.767748
# [89]	valid_0's auc: 0.767764
# [90]	valid_0's auc: 0.767947
# [91]	valid_0's auc: 0.767933
# [92]	valid_0's auc: 0.767931
# [93]	valid_0's auc: 0.767983
# [94]	valid_0's auc: 0.768075
# [95]	valid_0's auc: 0.768071
# [96]	valid_0's auc: 0.76809
# [97]	valid_0's auc: 0.768048
# [98]	valid_0's auc: 0.768006
# [99]	valid_0's auc: 0.768152
# [100]	valid_0's auc: 0.768147
# [101]	valid_0's auc: 0.768241
# [102]	valid_0's auc: 0.767918
# [103]	valid_0's auc: 0.767973
# [104]	valid_0's auc: 0.768123
# [105]	valid_0's auc: 0.768121
# [106]	valid_0's auc: 0.768146
# [107]	valid_0's auc: 0.768137
# [108]	valid_0's auc: 0.768082
# [109]	valid_0's auc: 0.76801
# [110]	valid_0's auc: 0.767977
# [111]	valid_0's auc: 0.768009
# [112]	valid_0's auc: 0.768123
# [113]	valid_0's auc: 0.768031
# [114]	valid_0's auc: 0.767986
# [115]	valid_0's auc: 0.767985
# [116]	valid_0's auc: 0.768087
# [117]	valid_0's auc: 0.768075
# [118]	valid_0's auc: 0.768125
# [119]	valid_0's auc: 0.768066
# [120]	valid_0's auc: 0.768077
# [121]	valid_0's auc: 0.768002
# [122]	valid_0's auc: 0.768019
# [123]	valid_0's auc: 0.76808
# [124]	valid_0's auc: 0.768169
# [125]	valid_0's auc: 0.768099
# [126]	valid_0's auc: 0.76807
# [127]	valid_0's auc: 0.768009
# [128]	valid_0's auc: 0.767974
# [129]	valid_0's auc: 0.767999
# [130]	valid_0's auc: 0.768072
# [131]	valid_0's auc: 0.768057
# Early stopping, best iteration is:
# [101]	valid_0's auc: 0.768241
# {'auc': {'trn': [0.8204822305402186], 'val': [0.7682410060831822]}}
#
# {'trn_auc_mean': 0.8204822305402186, 'val_auc_mean': 0.7682410060831822}
# CPU times: user 36.7 s, sys: 592 ms, total: 37.2 s
# Wall time: 8.18 s

# %%
# %%time
## previous week
y_test_0416, metrics, results, model = run_model(
            LGBMClassifier(n_estimators=100),
            val.drop(id_cols + [target_col], axis=1),
            val[target_col],
            train.drop(id_cols + [target_col], axis=1),
            train[target_col],
            test.drop(id_cols + [target_col, pred_col], axis=1),
            metric_names, results, 
            params_desc='n_estimators=100',
            dataset_desc='week_datediffs_0416')
# Out:
# LGBMClassifier
#
# [1]	valid_0's auc: 0.719847
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's auc: 0.727257
# [3]	valid_0's auc: 0.727494
# [4]	valid_0's auc: 0.733128
# [5]	valid_0's auc: 0.732506
# [6]	valid_0's auc: 0.733892
# [7]	valid_0's auc: 0.733932
# [8]	valid_0's auc: 0.734775
# [9]	valid_0's auc: 0.734852
# [10]	valid_0's auc: 0.735387
# [11]	valid_0's auc: 0.735663
# [12]	valid_0's auc: 0.736812
# [13]	valid_0's auc: 0.737172
# [14]	valid_0's auc: 0.737268
# [15]	valid_0's auc: 0.738106
# [16]	valid_0's auc: 0.740057
# [17]	valid_0's auc: 0.739857
# [18]	valid_0's auc: 0.739982
# [19]	valid_0's auc: 0.741471
# [20]	valid_0's auc: 0.742623
# [21]	valid_0's auc: 0.743457
# [22]	valid_0's auc: 0.744619
# [23]	valid_0's auc: 0.744891
# [24]	valid_0's auc: 0.745553
# [25]	valid_0's auc: 0.745355
# [26]	valid_0's auc: 0.745335
# [27]	valid_0's auc: 0.745714
# [28]	valid_0's auc: 0.74617
# [29]	valid_0's auc: 0.74626
# [30]	valid_0's auc: 0.746489
# [31]	valid_0's auc: 0.746917
# [32]	valid_0's auc: 0.747551
# [33]	valid_0's auc: 0.748042
# [34]	valid_0's auc: 0.748092
# [35]	valid_0's auc: 0.748365
# [36]	valid_0's auc: 0.748464
# [37]	valid_0's auc: 0.748497
# [38]	valid_0's auc: 0.748733
# [39]	valid_0's auc: 0.748789
# [40]	valid_0's auc: 0.749123
# [41]	valid_0's auc: 0.749373
# [42]	valid_0's auc: 0.749412
# [43]	valid_0's auc: 0.749499
# [44]	valid_0's auc: 0.749824
# [45]	valid_0's auc: 0.750796
# [46]	valid_0's auc: 0.750928
# [47]	valid_0's auc: 0.751222
# [48]	valid_0's auc: 0.751176
# [49]	valid_0's auc: 0.75122
# [50]	valid_0's auc: 0.751348
# [51]	valid_0's auc: 0.751594
# [52]	valid_0's auc: 0.751645
# [53]	valid_0's auc: 0.751895
# [54]	valid_0's auc: 0.752071
# [55]	valid_0's auc: 0.752412
# [56]	valid_0's auc: 0.75257
# [57]	valid_0's auc: 0.752706
# [58]	valid_0's auc: 0.752714
# [59]	valid_0's auc: 0.752979
# [60]	valid_0's auc: 0.752957
# [61]	valid_0's auc: 0.753202
# [62]	valid_0's auc: 0.752964
# [63]	valid_0's auc: 0.753242
# [64]	valid_0's auc: 0.75343
# [65]	valid_0's auc: 0.753468
# [66]	valid_0's auc: 0.753631
# [67]	valid_0's auc: 0.753492
# [68]	valid_0's auc: 0.753469
# [69]	valid_0's auc: 0.753505
# [70]	valid_0's auc: 0.753673
# [71]	valid_0's auc: 0.753739
# [72]	valid_0's auc: 0.753989
# [73]	valid_0's auc: 0.753886
# [74]	valid_0's auc: 0.753848
# [75]	valid_0's auc: 0.753835
# [76]	valid_0's auc: 0.753496
# [77]	valid_0's auc: 0.753728
# [78]	valid_0's auc: 0.753913
# [79]	valid_0's auc: 0.753969
# [80]	valid_0's auc: 0.753997
# [81]	valid_0's auc: 0.754263
# [82]	valid_0's auc: 0.754391
# [83]	valid_0's auc: 0.75431
# [84]	valid_0's auc: 0.75441
# [85]	valid_0's auc: 0.754442
# [86]	valid_0's auc: 0.754439
# [87]	valid_0's auc: 0.754421
# [88]	valid_0's auc: 0.754292
# [89]	valid_0's auc: 0.75413
# [90]	valid_0's auc: 0.754291
# [91]	valid_0's auc: 0.754327
# [92]	valid_0's auc: 0.754201
# [93]	valid_0's auc: 0.754244
# [94]	valid_0's auc: 0.754512
# [95]	valid_0's auc: 0.754247
# [96]	valid_0's auc: 0.754396
# [97]	valid_0's auc: 0.75437
# [98]	valid_0's auc: 0.754092
# [99]	valid_0's auc: 0.754092
# [100]	valid_0's auc: 0.754202
# Did not meet early stopping. Best iteration is:
# [94]	valid_0's auc: 0.754512
# {'auc': {'trn': [0.8293519974392184], 'val': [0.7545119427735888]}}
#
# {'trn_auc_mean': 0.8293519974392184, 'val_auc_mean': 0.7545119427735888}
# CPU times: user 30.8 s, sys: 640 ms, total: 31.4 s
# Wall time: 7.06 s

# %%
results
# Out:
#                dataset           model             params  time  trn_auc_mean  \
# 0       week_datediffs  LGBMClassifier  n_estimators=1000  8.05      0.820482
# 1  week_datediffs_0416  LGBMClassifier   n_estimators=100  6.97      0.829352
#
#    trn_auc_std  val_auc_mean  val_auc_std
# 0          0.0      0.768241          0.0
# 1          0.0      0.754512          0.0

# %%
pd.Series(y_test_0409).describe()
# Out:
# count    484758.000000
# mean          0.030416
# std           0.038004
# min           0.002028
# 25%           0.010079
# 50%           0.018833
# 75%           0.041508
# max           0.918418
# dtype: float64

# %%
pd.Series(y_test_0416).describe()
# Out:
# count    484758.000000
# mean          0.029725
# std           0.033532
# min           0.001999
# 25%           0.009525
# 50%           0.017800
# 75%           0.043501
# max           0.906194
# dtype: float64

# %%
test[target_col] = np.mean([y_test_0409, y_test_0416], axis=0)

# %%
test[target_col] = y_test_0416

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv(RAW/'sample_submission.csv', low_memory=False)
submission = pd.merge(submission[['PredictionIdx']], test[['PredictionIdx', target_col]], 
                      how='left', on='PredictionIdx')

# %%
submission[target_col].describe()
# Out:
# count    484758.000000
# mean          0.029725
# std           0.033532
# min           0.001999
# 25%           0.009525
# 50%           0.017800
# 75%           0.043501
# max           0.906194
# Name: CustomerInterest, dtype: float64

# %%
submission.head()
# Out:
#   PredictionIdx  CustomerInterest
# 0    a1e0d80784          0.057804
# 1    c2cc6cc2a8          0.076040
# 2    a8e94f6344          0.043556
# 3    758bae1e35          0.043243
# 4    02ab378ee8          0.043728

# %%
submission.to_csv(SUBMISSIONS/'07-lgbm_week_datediffs_dayscount_0416.csv', index=False)
